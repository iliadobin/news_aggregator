# %%
from app.nlp import normalize_text
from app.domain import Language

text = "Привет! Проверьте наш канал: https://t.me/example 🚀"
result = normalize_text(
    text,
    language=Language.AUTO,
    remove_urls=True,
    remove_emojis_flag=True,
)

print(f"Normalized: {result.normalized}")
print(f"Tokens: {result.tokens}")
print(f"Language: {result.language}")
print(f"Lemmas: {result.lemmas}")
# Out:
# Normalized: привет! проверьте наш канал:
# Tokens: ['привет', 'проверьте', 'наш', 'канал']
# Language: mk
# Lemmas: ['привет', 'проверьте', 'наш', 'канал']

# %%
from app.nlp import normalize_text
from app.domain import Language

text = "Привет! Проверьте наш канал: https://t.me/example 🚀"
result = normalize_text(
    text,
    language=Language.AUTO,
    remove_urls=True,
    remove_emojis_flag=True,
)

print(f"Normalized: {result.normalized}")
print(f"Tokens: {result.tokens}")
print(f"Language: {result.language}")
print(f"Lemmas: {result.lemmas}")
# Out:
# Normalized: привет! проверьте наш канал:
# Tokens: ['привет', 'проверьте', 'наш', 'канал']
# Language: mk
# Lemmas: ['привет', 'проверьте', 'наш', 'канал']
